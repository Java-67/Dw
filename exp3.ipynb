# %%
import pandas as pd
file_path1="XLS_Child-labour-database_July-2024.xlsx"
file_path2="XLS_Child-marriage-database_May-2024.xlsx"
df1=pd.read_excel(file_path1,sheet_name='Child labour')
df2=pd.read_excel(file_path2,sheet_name='Child marriage')
df1
# Out:
#                 Countries and areas Child labour (%)+ \n(2015-2023)*  \
# 0                       Afghanistan                             19.3
# 1                           Albania                              3.3
# 2                           Algeria                              2.5
# 3                           Andorra                                -
# 4                            Angola                             18.7
# ..                              ...                              ...
# 213     Eastern and Southern Africa                           28.098
# 214         West and Central Africa                           25.665
# 215       Least developed countries                           22.632
# 216                           World                                -
# 217                               1                                2
#
#     Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0          NaN       19.6        NaN         19        NaN
# 1          x,y        3.6        x,y          3        x,y
# 2          NaN        2.9        NaN          2        NaN
# 3          NaN          -        NaN          -        NaN
# 4          NaN       16.6        NaN       19.9        NaN
# ..         ...        ...        ...        ...        ...
# 213        NaN     30.136        NaN     25.771        NaN
# 214        NaN     25.915        NaN     25.399        NaN
# 215        NaN     23.457        NaN     21.674        NaN
# 216        NaN          -        NaN          -        NaN
# 217          3          4          5          6          7
#
#                                     Unnamed: 7
# 0    MICS 2022-23, UNICEF and ILO calculations
# 1        CLS 2010, UNICEF and ILO calculations
# 2    MICS 2018-19, UNICEF and ILO calculations
# 3                                          NaN
# 4     DHS 2015-16, UNICEF and ILO calculations
# ..                                         ...
# 213       DHS, MICS and other national surveys
# 214       DHS, MICS and other national surveys
# 215       DHS, MICS and other national surveys
# 216                                        NaN
# 217                                          8
#
# [218 rows x 8 columns]

# %%
merged_df=pd.merge(df1,df2,how='inner',on='Countries and areas')
merged_df
# Out:
#                     Countries and areas Child labour (%)+ \n(2015-2023)*  \
# 0                           Afghanistan                             19.3
# 1                               Albania                              3.3
# 2                               Algeria                              2.5
# 3                               Andorra                                -
# 4                                Angola                             18.7
# ..                                  ...                              ...
# 197  Venezuela (Bolivarian Republic of)                                -
# 198                            Viet Nam                              6.9
# 199                               Yemen                             15.9
# 200                              Zambia                               23
# 201                            Zimbabwe                             27.9
#
#     Unnamed: 2_x Unnamed: 3 Unnamed: 4_x Unnamed: 5 Unnamed: 6  \
# 0            NaN       19.6          NaN         19        NaN
# 1            x,y        3.6          x,y          3        x,y
# 2            NaN        2.9          NaN          2        NaN
# 3            NaN          -          NaN          -        NaN
# 4            NaN       16.6          NaN       19.9        NaN
# ..           ...        ...          ...        ...        ...
# 197          NaN          -          NaN          -        NaN
# 198          NaN        6.4          NaN        7.6        NaN
# 199            y       13.9            y       18.1          y
# 200            x       22.9            x         23          x
# 201          NaN       33.1          NaN       22.4        NaN
#
#                                             Unnamed: 7 Married by 15  \
# 0            MICS 2022-23, UNICEF and ILO calculations           9.6
# 1                CLS 2010, UNICEF and ILO calculations           1.4
# 2            MICS 2018-19, UNICEF and ILO calculations             0
# 3                                                  NaN             -
# 4             DHS 2015-16, UNICEF and ILO calculations           7.9
# ..                                                 ...           ...
# 197                                                NaN             -
# 198          MICS 2020-21, UNICEF and ILO calculations           1.1
# 199                                       MICS 2022-23           6.5
# 200  Labour Force and CLS 2012, UNICEF and ILO calc...           5.2
# 201             MICS 2019, UNICEF and ILO calculations           5.4
#
#     Unnamed: 2_y Married by 18 Unnamed: 4_y Reference year  \
# 0            NaN          28.7          NaN        2022-23
# 1            NaN          11.8          NaN        2017-18
# 2            NaN           3.8          NaN        2018-19
# 3            NaN             -          NaN            NaN
# 4            NaN          30.3          NaN        2015-16
# ..           ...           ...          ...            ...
# 197          NaN             -          NaN            NaN
# 198          NaN          14.6          NaN        2020-21
# 199            y          29.6            y        2022-23
# 200          NaN            29          NaN           2018
# 201          NaN          33.7          NaN           2019
#
#                                   Observation footnote   Data source  \
# 0                                                  NaN  MICS 2022-23
# 1                                                  NaN   DHS 2017-18
# 2                                                  NaN  MICS 2018-19
# 3                                                  NaN           NaN
# 4                                                  NaN   DHS 2015-16
# ..                                                 ...           ...
# 197                                                NaN           NaN
# 198                                                NaN  MICS 2020-21
# 199  41 out of the 880 selected enumeration areas c...  MICS 2022-23
# 200                                                NaN      DHS 2018
# 201                                                NaN     MICS 2019
#
#     Married by 18.1 Unnamed: 9 Reference year.1 Observation footnote.1  \
# 0               7.3        NaN             2015                    NaN
# 1               1.2        NaN          2017-18                    NaN
# 2                 -        NaN              NaN                    NaN
# 3                 -        NaN              NaN                    NaN
# 4                 6        NaN          2015-16                    NaN
# ..              ...        ...              ...                    ...
# 197               -        NaN              NaN                    NaN
# 198             1.9        NaN          2020-21                    NaN
# 199               -        NaN              NaN                    NaN
# 200             2.8        NaN             2018                    NaN
# 201             1.9        NaN             2019                    NaN
#
#     Data source.1
# 0        DHS 2015
# 1     DHS 2017-18
# 2             NaN
# 3             NaN
# 4     DHS 2015-16
# ..            ...
# 197           NaN
# 198  MICS 2020-21
# 199           NaN
# 200      DHS 2018
# 201     MICS 2019
#
# [202 rows x 20 columns]

# %%
merged_df.drop_duplicates(inplace=True)
merged_df
# Out:
#                     Countries and areas Child labour (%)+ \n(2015-2023)*  \
# 0                           Afghanistan                             19.3
# 1                               Albania                              3.3
# 2                               Algeria                              2.5
# 3                               Andorra                                -
# 4                                Angola                             18.7
# ..                                  ...                              ...
# 197  Venezuela (Bolivarian Republic of)                                -
# 198                            Viet Nam                              6.9
# 199                               Yemen                             15.9
# 200                              Zambia                               23
# 201                            Zimbabwe                             27.9
#
#     Unnamed: 2_x Unnamed: 3 Unnamed: 4_x Unnamed: 5 Unnamed: 6  \
# 0            NaN       19.6          NaN         19        NaN
# 1            x,y        3.6          x,y          3        x,y
# 2            NaN        2.9          NaN          2        NaN
# 3            NaN          -          NaN          -        NaN
# 4            NaN       16.6          NaN       19.9        NaN
# ..           ...        ...          ...        ...        ...
# 197          NaN          -          NaN          -        NaN
# 198          NaN        6.4          NaN        7.6        NaN
# 199            y       13.9            y       18.1          y
# 200            x       22.9            x         23          x
# 201          NaN       33.1          NaN       22.4        NaN
#
#                                             Unnamed: 7 Married by 15  \
# 0            MICS 2022-23, UNICEF and ILO calculations           9.6
# 1                CLS 2010, UNICEF and ILO calculations           1.4
# 2            MICS 2018-19, UNICEF and ILO calculations             0
# 3                                                  NaN             -
# 4             DHS 2015-16, UNICEF and ILO calculations           7.9
# ..                                                 ...           ...
# 197                                                NaN             -
# 198          MICS 2020-21, UNICEF and ILO calculations           1.1
# 199                                       MICS 2022-23           6.5
# 200  Labour Force and CLS 2012, UNICEF and ILO calc...           5.2
# 201             MICS 2019, UNICEF and ILO calculations           5.4
#
#     Unnamed: 2_y Married by 18 Unnamed: 4_y Reference year  \
# 0            NaN          28.7          NaN        2022-23
# 1            NaN          11.8          NaN        2017-18
# 2            NaN           3.8          NaN        2018-19
# 3            NaN             -          NaN            NaN
# 4            NaN          30.3          NaN        2015-16
# ..           ...           ...          ...            ...
# 197          NaN             -          NaN            NaN
# 198          NaN          14.6          NaN        2020-21
# 199            y          29.6            y        2022-23
# 200          NaN            29          NaN           2018
# 201          NaN          33.7          NaN           2019
#
#                                   Observation footnote   Data source  \
# 0                                                  NaN  MICS 2022-23
# 1                                                  NaN   DHS 2017-18
# 2                                                  NaN  MICS 2018-19
# 3                                                  NaN           NaN
# 4                                                  NaN   DHS 2015-16
# ..                                                 ...           ...
# 197                                                NaN           NaN
# 198                                                NaN  MICS 2020-21
# 199  41 out of the 880 selected enumeration areas c...  MICS 2022-23
# 200                                                NaN      DHS 2018
# 201                                                NaN     MICS 2019
#
#     Married by 18.1 Unnamed: 9 Reference year.1 Observation footnote.1  \
# 0               7.3        NaN             2015                    NaN
# 1               1.2        NaN          2017-18                    NaN
# 2                 -        NaN              NaN                    NaN
# 3                 -        NaN              NaN                    NaN
# 4                 6        NaN          2015-16                    NaN
# ..              ...        ...              ...                    ...
# 197               -        NaN              NaN                    NaN
# 198             1.9        NaN          2020-21                    NaN
# 199               -        NaN              NaN                    NaN
# 200             2.8        NaN             2018                    NaN
# 201             1.9        NaN             2019                    NaN
#
#     Data source.1
# 0        DHS 2015
# 1     DHS 2017-18
# 2             NaN
# 3             NaN
# 4     DHS 2015-16
# ..            ...
# 197           NaN
# 198  MICS 2020-21
# 199           NaN
# 200      DHS 2018
# 201     MICS 2019
#
# [202 rows x 20 columns]

# %%
missing_data_summary=merged_df.isnull().sum()
missing_data_summary
# Out:
# Countries and areas                   0
# Child labour (%)+ \n(2015-2023)*      0
# Unnamed: 2_x                        173
# Unnamed: 3                            0
# Unnamed: 4_x                        173
# Unnamed: 5                            0
# Unnamed: 6                          173
# Unnamed: 7                          103
# Married by 15                         0
# Unnamed: 2_y                        157
# Married by 18                         0
# Unnamed: 4_y                        155
# Reference year                       62
# Observation footnote                179
# Data source                          62
# Married by 18.1                       0
# Unnamed: 9                          169
# Reference year.1                    104
# Observation footnote.1              192
# Data source.1                       104
# dtype: int64

# %%
missing_data_summary=merged_df.isnull().sum()
merged_df.dropna(inplace=True)
merged_df
# Out:
#     Countries and areas Child labour (%)+ \n(2015-2023)* Unnamed: 2_x  \
# 18               Belize                              3.3            x
# 19                Benin                             19.9            y
# 130             Nigeria                             31.5            y
# 135            Pakistan                             11.4            y
#
#     Unnamed: 3 Unnamed: 4_x Unnamed: 5 Unnamed: 6  \
# 18         3.9            x        2.6          x
# 19        20.4            y       19.4          y
# 130         33            y         30          y
# 135       12.5            y       10.1          y
#
#                                    Unnamed: 7 Married by 15 Unnamed: 2_y  \
# 18      CAS 2013, UNICEF and ILO calculations           6.3            y
# 19                               MICS 2021-22           5.9            y
# 130                                 MICS 2021          12.3            y
# 135  LFS 2017-18, UNICEF and ILO calculations           3.6            y
#
#     Married by 18 Unnamed: 4_y Reference year  \
# 18           33.5            y        2015-16
# 19           27.5            y        2021-22
# 130          30.3            y           2021
# 135          18.3            y        2017-18
#
#                                   Observation footnote   Data source  \
# 18               Includes reference to visiting unions  MICS 2015-16
# 19   Two clusters could not be visited due to insec...  MICS 2021-22
# 130  Due to prolonged insecurity concerns, some par...     MICS 2021
# 135  Azad Jammu and Kashmir (AJK) and Gilgit Baltis...   DHS 2017-18
#
#     Married by 18.1 Unnamed: 9 Reference year.1  \
# 18             22.2          y          2015-16
# 19              4.6          y          2021-22
# 130             1.6          y             2021
# 135             4.7          y          2017-18
#
#                                 Observation footnote.1 Data source.1
# 18               Includes reference to visiting unions  MICS 2015-16
# 19   Two clusters could not be visited due to insec...  MICS 2021-22
# 130  Due to prolonged insecurity concerns, some par...     MICS 2021
# 135  Azad Jammu and Kashmir (AJK) and Gilgit Baltis...   DHS 2017-18

# %%
def clean_text(text):
    if instance(text, str):
        text=''.join(text.split())
        text=''.join(e for e in text if e.isalnum()or e.isspace())
        return text
        merged_df=merged_df.applymap(clean_text)
cleaned_file_path='cleaned_combained_data.xlsx'
merged_df.to_excel(cleaned_file_path,index=False)
print("summary of cleaning data:")
print(merged_df.info())
# Out:
# summary of cleaning data:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 18 to 135
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Countries and areas              4 non-null      object
#  1   Child labour (%)+
# (2015-2023)*  4 non-null      object
#  2   Unnamed: 2_x                     4 non-null      object
#  3   Unnamed: 3                       4 non-null      object
#  4   Unnamed: 4_x                     4 non-null      object
#  5   Unnamed: 5                       4 non-null      object
#  6   Unnamed: 6                       4 non-null      object
#  7   Unnamed: 7                       4 non-null      object
#  8   Married by 15                    4 non-null      object
#  9   Unnamed: 2_y                     4 non-null      object
#  10  Married by 18                    4 non-null      object
#  11  Unnamed: 4_y                     4 non-null      object
#  12  Reference year                   4 non-null      object
#  13  Observation footnote             4 non-null      object
#  14  Data source                      4 non-null      object
#  15  Married by 18.1                  4 non-null      object
#  16  Unnamed: 9                       4 non-null      object
#  17  Reference year.1                 4 non-null      object
#  18  Observation footnote.1           4 non-null      object
#  19  Data source.1                    4 non-null      object
# dtypes: object(20)
# memory usage: 672.0+ bytes
# None
